# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
import pandas as pd
import numpy as np

# %%
fig, ax = plt.subplots()

x = np.linspace(0,10,300)

y = np.sin(x) + x

ax.plot(x, y)

fig.show()
# Out:
# C:\Users\ashal\AppData\Local\Temp\ipykernel_6436\877309925.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
x = [2,3,4,5]
y = [7,6,3,5]

plt.plot(x,y)

# %%
x = [2,3,4,5]
y = [7,6,3,5]

plt.subplot(1,2,1)
plt.plot(x,y,"o")

x = [2,3,4,5]
y = [7,6,3,5]
plt.subplot(1,2,2)
plt.plot(x,y, marker = 'v')

# %%
x = np.array([10,14,30,60,80])
y = np.array([20,30,50,90,35])


#plt.plot(x,y,"y") #for clour yellow

# plt.plot(x,y, "o:b" )  #marker and color both

# plt.plot(x,y, "o-.b", ms = 20, mec = "r", mfc = "y")  #marker + line + color all, ms = marker size, mec = markeredgecolor , mfc = markerfacecolor 

# plt.plot(x, linestyle = "dotted")
# plt.plot(x, linestyle = 'dashed')
# plt.plot(x, linestyle = 'dashdot', linewidth = '10')

plt.plot(x,y)
plt.title("Plot", loc = 'right')
plt.xlabel("x axis")
plt.ylabel("y axis")
#plt.grid()
plt.grid(axis = 'x')

# %%
fig, ax = plt.subplots()

x = np.array([10,14,30,60,80])
y = np.array([20,30,50,90,35])

plt.plot(x,y)

plt.show()

# %% [markdown]
# The subplot() function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument. The third argument represents the index of the current plot.

# %%
x = np.linspace(1,11,200)
y = np.sin(x) + x

plt.subplot(1,2,1)
#the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)

x = np.linspace(20,50,400)
y = np.cos(x) + x

plt.subplot(1,2,2)
plt.plot(x,y)



plt.show()

# %%
x = np.linspace(1,11,200)
y = np.sin(x) + x

plt.subplot(2,1,1)
#the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)

x = np.linspace(20,50,400)
y = np.cos(x) + x

plt.subplot(2,1,2)
plt.plot(x,y)



plt.show()

# %% [markdown]
# You can draw as many plots you like on one figure, just descibe the number of rows, columns, and the index of the plot.

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)
plt.title("Sales")

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)
plt.title("Age")

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)


plt.suptitle("6 plots")
plt.show()

# %%
df = pd.read_csv("D:/AI_ML/Pandas/salary predicion dropped.csv")
df
# Out:
#      FIRST NAME  LAST NAME SEX         DOJ CURRENT DATE     DESIGNATION   AGE  \
# 0        TOMASA      ARMEN   F   5-18-2014   01-07-2016         Analyst  21.0
# 1         OLIVE       ANCY   F   7-28-2014   01-07-2016         Analyst  21.0
# 2        CHERRY    AQUILAR   F  04-03-2013   01-07-2016         Analyst  22.0
# 3        ELLIOT     AGULAR   M  09-02-2013   01-07-2016         Analyst  22.0
# 4         KATHY      ALSOP   F   6-29-2014   01-07-2016  Senior Analyst  28.0
# ...         ...        ...  ..         ...          ...             ...   ...
# 2626  KATHERINE     ALSDON   F   6-28-2011   01-07-2016  Senior Manager  36.0
# 2627     LOUISE    ALTARAS   F   1-14-2014   01-07-2016         Analyst  23.0
# 2628      RENEE     ALVINO   F   1-23-2014   01-07-2016         Analyst  21.0
# 2629       TERI  ANASTASIO   F   3-17-2014   01-07-2016         Analyst  24.0
# 2630    GREGORY     ABARCA   M   9-18-2014   01-07-2016         Analyst  24.0
#
# ...

# %%
x = df['AGE']
y = df["SALARY"]
plt.xlabel("AGE")
plt.ylabel("SALARY")


plt.scatter(x,y, color = 'hotpink', alpha = 0.2)  #alpha is to adjust the transparency of the dots 
plt.colorbar()

# %%
plt.xlabel("AGE")
plt.ylabel("SALARY")

# plt.bar(x,y, width = 0.8)
plt.barh(x,y, color = 'red', height = 0.5 )

plt.show()

# %%
plt.hist(np.random.normal(170, 10, 250))
# Out:
# (array([ 1.,  8., 17., 43., 60., 60., 37., 15.,  7.,  2.]),
#  array([138.92183556, 145.18232634, 151.44281712, 157.7033079 ,
#         163.96379868, 170.22428946, 176.48478024, 182.74527102,
#         189.0057618 , 195.26625258, 201.52674336]),
#  <BarContainer object of 10 artists>)

# %%
a = np.array([12,54,34,78])

plt.pie(a, labels = ['car','bike','truck','boat'],startangle=180, explode=[0.3,0,0,0.1])

plt.show()

# %%
a = np.array([12,54,34,78])

col = ['red','black','blue','yellow']
plt.pie(a, labels = ['car','bike','truck','boat'],startangle=180, colors=col)

plt.legend(title = 'Vehicles', loc = 2)
plt.show()

# %%
plt.boxplot(df['AGE'],)

plt.show()

# %%
data = np.random.random(( 12 , 12 )) 
plt.imshow( data ) 
  
plt.title( "2-D Heat Map" ) 
plt.show()
